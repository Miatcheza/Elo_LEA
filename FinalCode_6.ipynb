# %%
import pandas as pd
import numpy as np

from catboost import Pool, CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import warnings
import datetime
import time
import gc

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
# Importation du dataset new_merchant_transactions
df_new_merchant = pd.read_csv("../data_sets/new_merchant_transactions.csv",parse_dates=['purchase_date'])
print(df_new_merchant.shape)
df_new_merchant.head(5)
# Out:
# (1963031, 14)
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount       purchase_date  category_2  state_id  subsector_id
# 0        -0.557574 2018-03-11 14:57:36         1.0         9            19
# 1        -0.569580 2018-03-19 18:53:37         1.0         9            19
# 2        -0.551037 2018-04-26 14:08:44         1.0         9            14
# 3        -0.671925 2018-03-07 09:43:21         NaN        -1             8
# 4        -0.659904 2018-03-22 21:07:53         NaN        -1            29

# %%
# Importation du dataset historical_transactions
df_histo = pd.read_csv("../data_sets/historical_transactions.csv",parse_dates=['purchase_date'])
print(df_histo.shape)
df_histo.head(5)
# Out:
# (29112361, 14)
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_4e6213e9bc       88          N             0
# 1               Y  C_ID_4e6213e9bc       88          N             0
# 2               Y  C_ID_4e6213e9bc       88          N             0
# 3               Y  C_ID_4e6213e9bc       88          N             0
# 4               Y  C_ID_4e6213e9bc       88          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount       purchase_date  category_2  state_id  subsector_id
# 0        -0.703331 2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128 2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386 2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352 2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865 2017-03-10 01:14:19         1.0        16            37

# %%
# Importation du dataset train
df_train = pd.read_csv('../data_sets/train.csv')
# Importation du dataset test
df_test = pd.read_csv('../data_sets/test.csv')

# %%
# Remplacement des valeurs NaN
# Ces transformations sont pour le historical et le new merchant
for df in [df_histo,df_new_merchant]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
# Transformer 'purchase_date' en datetime, et modifier les valeurs de 'authorized_flag' et 'category_1' par 0 et 1
# Calcule du différentiel temporel entre aujourd'hui et la date d'achat du client en mois et lui ajouter le décalage associé
# Ces transformations sont pour le historical et le new merchant
for df in [df_histo,df_new_merchant]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']

# %%
df_histo.head(5)
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0                1  C_ID_4e6213e9bc       88           0             0
# 1                1  C_ID_4e6213e9bc       88           0             0
# 2                1  C_ID_4e6213e9bc       88           0             0
# 3                1  C_ID_4e6213e9bc       88           0             0
# 4                1  C_ID_4e6213e9bc       88           0             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount       purchase_date  category_2  state_id  subsector_id  \
# 0        -0.703331 2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128 2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386 2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352 2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865 2017-03-10 01:14:19         1.0        16            37
#
#    month_diff
# 0          13
# 1          13
# 2          13
# 3          13
# 4          13

# %%
# Fonction pour le renommage des nouvelles colonnes
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
# Calcule des nouvelles colonnes pour le historical_transactions
# Ces nouvelles colonnes seront ajoutées dans le train et le test
aggs = {}
for col in ['subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_histo[col+'_mean'] = df_histo.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist',aggs)
print (new_columns)
df_hist_trans_group = df_histo.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# ['hist_subsector_id_nunique', 'hist_merchant_id_nunique', 'hist_merchant_category_id_nunique', 'hist_purchase_amount_sum', 'hist_purchase_amount_max', 'hist_purchase_amount_min', 'hist_purchase_amount_mean', 'hist_purchase_amount_var', 'hist_installments_sum', 'hist_installments_max', 'hist_installments_min', 'hist_installments_mean', 'hist_installments_var', 'hist_purchase_date_max', 'hist_purchase_date_min', 'hist_month_lag_max', 'hist_month_lag_min', 'hist_month_lag_mean', 'hist_month_lag_var', 'hist_month_diff_mean', 'hist_authorized_flag_sum', 'hist_authorized_flag_mean', 'hist_category_1_sum', 'hist_category_1_mean', 'hist_card_id_size', 'hist_category_2_mean_mean', 'hist_category_3_mean_mean']
# 42

# %%
# Calcule des nouvelles colonnes pour le new_merchant_transactions
# Ces nouvelles colonnes seront ajoutées dans le train et le test
aggs = {}
for col in ['subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_new_merchant[col+'_mean'] = df_new_merchant.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_merchant',aggs)
df_hist_trans_group = df_new_merchant.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
print (new_columns)
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_merchant_purchase_date_diff'] = (df_hist_trans_group['new_merchant_purchase_date_max'] - df_hist_trans_group['new_merchant_purchase_date_min']).dt.days
df_hist_trans_group['new_merchant_purchase_date_average'] = df_hist_trans_group['new_merchant_purchase_date_diff']/df_hist_trans_group['new_merchant_card_id_size']
df_hist_trans_group['new_merchant_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_merchant_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# ['new_merchant_subsector_id_nunique', 'new_merchant_merchant_id_nunique', 'new_merchant_merchant_category_id_nunique', 'new_merchant_purchase_amount_sum', 'new_merchant_purchase_amount_max', 'new_merchant_purchase_amount_min', 'new_merchant_purchase_amount_mean', 'new_merchant_purchase_amount_var', 'new_merchant_installments_sum', 'new_merchant_installments_max', 'new_merchant_installments_min', 'new_merchant_installments_mean', 'new_merchant_installments_var', 'new_merchant_purchase_date_max', 'new_merchant_purchase_date_min', 'new_merchant_month_lag_max', 'new_merchant_month_lag_min', 'new_merchant_month_lag_mean', 'new_merchant_month_lag_var', 'new_merchant_month_diff_mean', 'new_merchant_category_1_sum', 'new_merchant_category_1_mean', 'new_merchant_card_id_size', 'new_merchant_category_2_mean_mean', 'new_merchant_category_3_mean_mean']
# 28

# %%
# Libérer de l'espace avec le garbage collector
del df_histo;gc.collect()
del df_new_merchant;gc.collect()
df_train.head(5)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_subsector_id_nunique  hist_merchant_id_nunique  \
# 0 -0.820283                         21                        94
# 1  0.392913                         24                       142
# 2  0.688056                          7                        13
# 3  0.142495                         13                        50
# 4 -0.159749                         17                        66
#
#    hist_merchant_category_id_nunique  hist_purchase_amount_sum  \
# 0                                 41               -165.968739
# 1                                 57               -210.006336
# 2                                  8                -29.167391
# 3                                 25                -49.491364
# 4                                 26                -48.687656
#
#                  ...                  new_merchant_month_lag_var  \
# 0                ...                                    0.260870
# 1                ...                                    0.300000
# 2                ...                                         NaN
# 3                ...                                    0.238095
# 4                ...                                    0.253968
#
#    new_merchant_month_diff_mean  new_merchant_category_1_sum  \
# 0                     12.695652                          0.0
# 1                     13.833333                          0.0
# 2                     12.000000                          0.0
# 3                     13.000000                          1.0
# 4                     12.833333                          2.0
#
#    new_merchant_category_1_mean  new_merchant_card_id_size  \
# 0                      0.000000                       23.0
# 1                      0.000000                        6.0
# 2                      0.000000                        1.0
# 3                      0.142857                        7.0
# 4                      0.055556                       36.0
#
#    new_merchant_category_2_mean_mean  new_merchant_category_3_mean_mean  \
# 0                          -0.550160                          -0.592993
# 1                          -0.550160                          -0.606486
# 2                          -0.549015                          -0.592993
# 3                          -0.556518                          -0.604559
# 4                          -0.555446                          -0.588217
#
#    new_merchant_purchase_date_diff  new_merchant_purchase_date_average  \
# 0                             54.0                            2.347826
# 1                             56.0                            9.333333
# 2                              0.0                            0.000000
# 3                             41.0                            5.857143
# 4                             57.0                            1.583333
#
#   new_merchant_purchase_date_uptonow
# 0                              325.0
# 1                              355.0
# 2                              326.0
# 3                              336.0
# 4                              326.0
#
# [5 rows x 64 columns]

# %%
# Calcule de la nouvelle colonne 'outliers' pour le train
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
# Transformer 'first_active_month' en datetime, et calcule du temps passé entre aujourd'hui et la date du 1er achat
# Calcule du nombre de fois qu'une 'card_id' a été utilisé dans le historical et le new merchant
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    
    df['card_id_total'] = df['new_merchant_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_merchant_purchase_amount_sum']+df['hist_purchase_amount_sum']

# Calcule des nouveaux features qui correspondent au mean par outliers par rapport aux features
# Ces transformations sont pour le train et le test
for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    print(f,"order_label",order_label)
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)
# Out:
# feature_1 order_label feature_1
# 1    0.008058
# 2    0.010610
# 3    0.010479
# 4    0.010712
# 5    0.013145
# Name: outliers, dtype: float64
# feature_2 order_label feature_2
# 1    0.011385
# 2    0.008752
# 3    0.014166
# Name: outliers, dtype: float64
# feature_3 order_label feature_3
# 0    0.010283
# 1    0.011428
# Name: outliers, dtype: float64

# %%
print(df_train.shape)
df_train.head(5)
# Out:
# (201917, 68)
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557   0.013145   0.008752   0.011428
# 1         2017-01-01  C_ID_3d0044924f   0.010712   0.011385   0.010283
# 2         2016-08-01  C_ID_d639edf6cd   0.010610   0.008752   0.010283
# 3         2017-09-01  C_ID_186d6a6901   0.010712   0.014166   0.010283
# 4         2017-11-01  C_ID_cdbd2c0db2   0.008058   0.014166   0.010283
#
#      target  hist_subsector_id_nunique  hist_merchant_id_nunique  \
# 0 -0.820283                         21                        94
# 1  0.392913                         24                       142
# 2  0.688056                          7                        13
# 3  0.142495                         13                        50
# 4 -0.159749                         17                        66
#
#    hist_merchant_category_id_nunique  hist_purchase_amount_sum  \
# 0                                 41               -165.968739
# 1                                 57               -210.006336
# 2                                  8                -29.167391
# 3                                 25                -49.491364
# 4                                 26                -48.687656
#
#            ...           new_merchant_card_id_size  \
# 0          ...                                23.0
# 1          ...                                 6.0
# 2          ...                                 1.0
# 3          ...                                 7.0
# 4          ...                                36.0
#
#    new_merchant_category_2_mean_mean  new_merchant_category_3_mean_mean  \
# 0                          -0.550160                          -0.592993
# 1                          -0.550160                          -0.606486
# 2                          -0.549015                          -0.592993
# 3                          -0.556518                          -0.604559
# 4                          -0.555446                          -0.588217
#
#    new_merchant_purchase_date_diff  new_merchant_purchase_date_average  \
# 0                             54.0                            2.347826
# 1                             56.0                            9.333333
# 2                              0.0                            0.000000
# 3                             41.0                            5.857143
# 4                             57.0                            1.583333
#
#    new_merchant_purchase_date_uptonow  outliers  elapsed_time  card_id_total  \
# 0                               325.0         0           657          283.0
# 1                               355.0         0           808          356.0
# 2                               326.0         0           961           44.0
# 3                               336.0         0           565           84.0
# 4                               326.0         0           504          169.0
#
#   purchase_amount_total
# 0           -179.212942
# 1           -214.362071
# 2            -29.867717
# 3            -54.145736
# 4            -68.613893
#
# [5 rows x 68 columns]

# %%
# Retirer la colonnes target du train
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
print(df_train_columns)
target = df_train['target']
del df_train['target']
# Out:
# ['feature_1', 'feature_2', 'feature_3', 'hist_subsector_id_nunique', 'hist_merchant_id_nunique', 'hist_merchant_category_id_nunique', 'hist_purchase_amount_sum', 'hist_purchase_amount_max', 'hist_purchase_amount_min', 'hist_purchase_amount_mean', 'hist_purchase_amount_var', 'hist_installments_sum', 'hist_installments_max', 'hist_installments_min', 'hist_installments_mean', 'hist_installments_var', 'hist_purchase_date_max', 'hist_purchase_date_min', 'hist_month_lag_max', 'hist_month_lag_min', 'hist_month_lag_mean', 'hist_month_lag_var', 'hist_month_diff_mean', 'hist_authorized_flag_sum', 'hist_authorized_flag_mean', 'hist_category_1_sum', 'hist_category_1_mean', 'hist_card_id_size', 'hist_category_2_mean_mean', 'hist_category_3_mean_mean', 'hist_purchase_date_diff', 'hist_purchase_date_average', 'hist_purchase_date_uptonow', 'new_merchant_subsector_id_nunique', 'new_merchant_merchant_id_nunique', 'new_merchant_merchant_category_id_nunique', 'new_merchant_purchase_amount_sum', 'new_merchant_purchase_amount_max', 'new_merchant_purchase_amount_min', 'new_merchant_purchase_amount_mean', 'new_merchant_purchase_amount_var', 'new_merchant_installments_sum', 'new_merchant_installments_max', 'new_merchant_installments_min', 'new_merchant_installments_mean', 'new_merchant_installments_var', 'new_merchant_purchase_date_max', 'new_merchant_purchase_date_min', 'new_merchant_month_lag_max', 'new_merchant_month_lag_min', 'new_merchant_month_lag_mean', 'new_merchant_month_lag_var', 'new_merchant_month_diff_mean', 'new_merchant_category_1_sum', 'new_merchant_category_1_mean', 'new_merchant_card_id_size', 'new_merchant_category_2_mean_mean', 'new_merchant_category_3_mean_mean', 'new_merchant_purchase_date_diff', 'new_merchant_purchase_date_average', 'new_merchant_purchase_date_uptonow', 'elapsed_time', 'card_id_total', 'purchase_amount_total']

# %%
print(df_test.shape)
df_test.head(5)
# Out:
# (123623, 66)
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-04-01  C_ID_0ab67a22ab   0.010479   0.014166   0.011428
# 1         2017-01-01  C_ID_130fd0cbdd   0.010610   0.014166   0.010283
# 2         2017-08-01  C_ID_b709037bc5   0.013145   0.011385   0.011428
# 3         2017-12-01  C_ID_d27d835a9f   0.010610   0.011385   0.010283
# 4         2015-12-01  C_ID_2b5e3df5c2   0.013145   0.011385   0.011428
#
#    hist_subsector_id_nunique  hist_merchant_id_nunique  \
# 0                         12                        24
# 1                         12                        27
# 2                          6                         9
# 3                         11                        23
# 4                         15                        47
#
#    hist_merchant_category_id_nunique  hist_purchase_amount_sum  \
# 0                                 16                -40.733733
# 1                                 16                -49.136513
# 2                                  8                  4.528840
# 3                                 18                -13.690715
# 4                                 31                 25.139384
#
#    hist_purchase_amount_max          ...           \
# 0                  0.235676          ...
# 1                  0.318817          ...
# 2                  2.525866          ...
# 3                  0.087965          ...
# 4                 15.782255          ...
#
#    new_merchant_category_1_mean  new_merchant_card_id_size  \
# 0                      0.000000                        3.0
# 1                      0.222222                        9.0
# 2                      0.500000                        2.0
# 3                      0.100000                       10.0
# 4                      0.000000                        6.0
#
#    new_merchant_category_2_mean_mean  new_merchant_category_3_mean_mean  \
# 0                          -0.550160                          -0.391755
# 1                          -0.555930                          -0.534909
# 2                          -0.549587                          -0.284389
# 3                          -0.550046                          -0.284389
# 4                          -0.556457                          -0.496872
#
#    new_merchant_purchase_date_diff  new_merchant_purchase_date_average  \
# 0                             25.0                            8.333333
# 1                             48.0                            5.333333
# 2                             11.0                            5.500000
# 3                             44.0                            4.400000
# 4                             39.0                            6.500000
#
#    new_merchant_purchase_date_uptonow  elapsed_time card_id_total  \
# 0                               385.0         718.0          71.0
# 1                               334.0         808.0          87.0
# 2                               372.0         596.0          15.0
# 3                               337.0         474.0          36.0
# 4                               342.0        1205.0         116.0
#
#   purchase_amount_total
# 0            -42.510888
# 1            -55.081212
# 2              4.708978
# 3            -19.434389
# 4             37.204381
#
# [5 rows x 66 columns]

# %%
df_train.columns.difference(df_test.columns)
# Out:
# Index(['outliers'], dtype='object')

# %%
# Mettre le 'card_id' comme index pour le train
df_train = df_train.set_index("card_id")
df_train.head(5)
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  \
# card_id
# C_ID_92a2005557         2017-06-01   0.013145   0.008752   0.011428
# C_ID_3d0044924f         2017-01-01   0.010712   0.011385   0.010283
# C_ID_d639edf6cd         2016-08-01   0.010610   0.008752   0.010283
# C_ID_186d6a6901         2017-09-01   0.010712   0.014166   0.010283
# C_ID_cdbd2c0db2         2017-11-01   0.008058   0.014166   0.010283
#
#                  hist_subsector_id_nunique  hist_merchant_id_nunique  \
# card_id
# C_ID_92a2005557                         21                        94
# C_ID_3d0044924f                         24                       142
# C_ID_d639edf6cd                          7                        13
# C_ID_186d6a6901                         13                        50
# C_ID_cdbd2c0db2                         17                        66
#
#                  hist_merchant_category_id_nunique  hist_purchase_amount_sum  \
# card_id
# C_ID_92a2005557                                 41               -165.968739
# C_ID_3d0044924f                                 57               -210.006336
# C_ID_d639edf6cd                                  8                -29.167391
# C_ID_186d6a6901                                 25                -49.491364
# C_ID_cdbd2c0db2                                 26                -48.687656
#
#                  hist_purchase_amount_max  hist_purchase_amount_min  \
# card_id
# C_ID_92a2005557                  2.258395                 -0.739395
# C_ID_3d0044924f                  4.630299                 -0.742400
# C_ID_d639edf6cd                 -0.145847                 -0.730138
# C_ID_186d6a6901                  1.445596                 -0.740897
# C_ID_cdbd2c0db2                  7.193041                 -0.746156
#
#                          ...            new_merchant_card_id_size  \
# card_id                  ...
# C_ID_92a2005557          ...                                 23.0
# C_ID_3d0044924f          ...                                  6.0
# C_ID_d639edf6cd          ...                                  1.0
# C_ID_186d6a6901          ...                                  7.0
# C_ID_cdbd2c0db2          ...                                 36.0
#
#                  new_merchant_category_2_mean_mean  \
# card_id
# C_ID_92a2005557                          -0.550160
# C_ID_3d0044924f                          -0.550160
# C_ID_d639edf6cd                          -0.549015
# C_ID_186d6a6901                          -0.556518
# C_ID_cdbd2c0db2                          -0.555446
#
#                  new_merchant_category_3_mean_mean  \
# card_id
# C_ID_92a2005557                          -0.592993
# C_ID_3d0044924f                          -0.606486
# C_ID_d639edf6cd                          -0.592993
# C_ID_186d6a6901                          -0.604559
# C_ID_cdbd2c0db2                          -0.588217
#
#                  new_merchant_purchase_date_diff  \
# card_id
# C_ID_92a2005557                             54.0
# C_ID_3d0044924f                             56.0
# C_ID_d639edf6cd                              0.0
# C_ID_186d6a6901                             41.0
# C_ID_cdbd2c0db2                             57.0
#
#                  new_merchant_purchase_date_average  \
# card_id
# C_ID_92a2005557                            2.347826
# C_ID_3d0044924f                            9.333333
# C_ID_d639edf6cd                            0.000000
# C_ID_186d6a6901                            5.857143
# C_ID_cdbd2c0db2                            1.583333
#
#                  new_merchant_purchase_date_uptonow  outliers elapsed_time  \
# card_id
# C_ID_92a2005557                               325.0         0          657
# C_ID_3d0044924f                               355.0         0          808
# C_ID_d639edf6cd                               326.0         0          961
# C_ID_186d6a6901                               336.0         0          565
# C_ID_cdbd2c0db2                               326.0         0          504
#
#                 card_id_total  purchase_amount_total
# card_id
# C_ID_92a2005557         283.0            -179.212942
# C_ID_3d0044924f         356.0            -214.362071
# C_ID_d639edf6cd          44.0             -29.867717
# C_ID_186d6a6901          84.0             -54.145736
# C_ID_cdbd2c0db2         169.0             -68.613893
#
# [5 rows x 66 columns]

# %%
# Mettre le 'card_id' comme index pour le test
df_test = df_test.set_index("card_id")
df_test.head(5)
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  \
# card_id
# C_ID_0ab67a22ab         2017-04-01   0.010479   0.014166   0.011428
# C_ID_130fd0cbdd         2017-01-01   0.010610   0.014166   0.010283
# C_ID_b709037bc5         2017-08-01   0.013145   0.011385   0.011428
# C_ID_d27d835a9f         2017-12-01   0.010610   0.011385   0.010283
# C_ID_2b5e3df5c2         2015-12-01   0.013145   0.011385   0.011428
#
#                  hist_subsector_id_nunique  hist_merchant_id_nunique  \
# card_id
# C_ID_0ab67a22ab                         12                        24
# C_ID_130fd0cbdd                         12                        27
# C_ID_b709037bc5                          6                         9
# C_ID_d27d835a9f                         11                        23
# C_ID_2b5e3df5c2                         15                        47
#
#                  hist_merchant_category_id_nunique  hist_purchase_amount_sum  \
# card_id
# C_ID_0ab67a22ab                                 16                -40.733733
# C_ID_130fd0cbdd                                 16                -49.136513
# C_ID_b709037bc5                                  8                  4.528840
# C_ID_d27d835a9f                                 18                -13.690715
# C_ID_2b5e3df5c2                                 31                 25.139384
#
#                  hist_purchase_amount_max  hist_purchase_amount_min  \
# card_id
# C_ID_0ab67a22ab                  0.235676                 -0.743902
# C_ID_130fd0cbdd                  0.318817                 -0.731881
# C_ID_b709037bc5                  2.525866                 -0.536537
# C_ID_d27d835a9f                  0.087965                 -0.731881
# C_ID_2b5e3df5c2                 15.782255                 -0.746758
#
#                          ...            new_merchant_category_1_mean  \
# card_id                  ...
# C_ID_0ab67a22ab          ...                                0.000000
# C_ID_130fd0cbdd          ...                                0.222222
# C_ID_b709037bc5          ...                                0.500000
# C_ID_d27d835a9f          ...                                0.100000
# C_ID_2b5e3df5c2          ...                                0.000000
#
#                  new_merchant_card_id_size  new_merchant_category_2_mean_mean  \
# card_id
# C_ID_0ab67a22ab                        3.0                          -0.550160
# C_ID_130fd0cbdd                        9.0                          -0.555930
# C_ID_b709037bc5                        2.0                          -0.549587
# C_ID_d27d835a9f                       10.0                          -0.550046
# C_ID_2b5e3df5c2                        6.0                          -0.556457
#
#                  new_merchant_category_3_mean_mean  \
# card_id
# C_ID_0ab67a22ab                          -0.391755
# C_ID_130fd0cbdd                          -0.534909
# C_ID_b709037bc5                          -0.284389
# C_ID_d27d835a9f                          -0.284389
# C_ID_2b5e3df5c2                          -0.496872
#
#                  new_merchant_purchase_date_diff  \
# card_id
# C_ID_0ab67a22ab                             25.0
# C_ID_130fd0cbdd                             48.0
# C_ID_b709037bc5                             11.0
# C_ID_d27d835a9f                             44.0
# C_ID_2b5e3df5c2                             39.0
#
#                  new_merchant_purchase_date_average  \
# card_id
# C_ID_0ab67a22ab                            8.333333
# C_ID_130fd0cbdd                            5.333333
# C_ID_b709037bc5                            5.500000
# C_ID_d27d835a9f                            4.400000
# C_ID_2b5e3df5c2                            6.500000
#
#                  new_merchant_purchase_date_uptonow elapsed_time  \
# card_id
# C_ID_0ab67a22ab                               385.0        718.0
# C_ID_130fd0cbdd                               334.0        808.0
# C_ID_b709037bc5                               372.0        596.0
# C_ID_d27d835a9f                               337.0        474.0
# C_ID_2b5e3df5c2                               342.0       1205.0
#
#                 card_id_total  purchase_amount_total
# card_id
# C_ID_0ab67a22ab          71.0             -42.510888
# C_ID_130fd0cbdd          87.0             -55.081212
# C_ID_b709037bc5          15.0               4.708978
# C_ID_d27d835a9f          36.0             -19.434389
# C_ID_2b5e3df5c2         116.0              37.204381
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Nettoyage des données

# %%
# Retirer les colonnes inutiles du train
listOfOuts = ["new_merchant_purchase_date_max","new_merchant_purchase_date_min",
              "new_merchant_merchant_category_id_nunique",
              "new_merchant_merchant_id_nunique","hist_authorized_flag_mean","hist_authorized_flag_sum",
              "hist_purchase_date_max","hist_purchase_date_min","hist_merchant_id_nunique",
              "hist_merchant_category_id_nunique"]

df_train = df_train.drop(listOfOuts, axis=1)
df_train = df_train.drop("outliers", axis=1)
df_train.head(5)
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  \
# card_id
# C_ID_92a2005557         2017-06-01   0.013145   0.008752   0.011428
# C_ID_3d0044924f         2017-01-01   0.010712   0.011385   0.010283
# C_ID_d639edf6cd         2016-08-01   0.010610   0.008752   0.010283
# C_ID_186d6a6901         2017-09-01   0.010712   0.014166   0.010283
# C_ID_cdbd2c0db2         2017-11-01   0.008058   0.014166   0.010283
#
#                  hist_subsector_id_nunique  hist_purchase_amount_sum  \
# card_id
# C_ID_92a2005557                         21               -165.968739
# C_ID_3d0044924f                         24               -210.006336
# C_ID_d639edf6cd                          7                -29.167391
# C_ID_186d6a6901                         13                -49.491364
# C_ID_cdbd2c0db2                         17                -48.687656
#
#                  hist_purchase_amount_max  hist_purchase_amount_min  \
# card_id
# C_ID_92a2005557                  2.258395                 -0.739395
# C_ID_3d0044924f                  4.630299                 -0.742400
# C_ID_d639edf6cd                 -0.145847                 -0.730138
# C_ID_186d6a6901                  1.445596                 -0.740897
# C_ID_cdbd2c0db2                  7.193041                 -0.746156
#
#                  hist_purchase_amount_mean  hist_purchase_amount_var  \
# card_id
# C_ID_92a2005557                  -0.638341                  0.045003
# C_ID_3d0044924f                  -0.600018                  0.148200
# C_ID_d639edf6cd                  -0.678311                  0.007635
# C_ID_186d6a6901                  -0.642745                  0.068447
# C_ID_cdbd2c0db2                  -0.366073                  1.828160
#
#                          ...            new_merchant_category_1_mean  \
# card_id                  ...
# C_ID_92a2005557          ...                                0.000000
# C_ID_3d0044924f          ...                                0.000000
# C_ID_d639edf6cd          ...                                0.000000
# C_ID_186d6a6901          ...                                0.142857
# C_ID_cdbd2c0db2          ...                                0.055556
#
#                  new_merchant_card_id_size  new_merchant_category_2_mean_mean  \
# card_id
# C_ID_92a2005557                       23.0                          -0.550160
# C_ID_3d0044924f                        6.0                          -0.550160
# C_ID_d639edf6cd                        1.0                          -0.549015
# C_ID_186d6a6901                        7.0                          -0.556518
# C_ID_cdbd2c0db2                       36.0                          -0.555446
#
#                  new_merchant_category_3_mean_mean  \
# card_id
# C_ID_92a2005557                          -0.592993
# C_ID_3d0044924f                          -0.606486
# C_ID_d639edf6cd                          -0.592993
# C_ID_186d6a6901                          -0.604559
# C_ID_cdbd2c0db2                          -0.588217
#
#                  new_merchant_purchase_date_diff  \
# card_id
# C_ID_92a2005557                             54.0
# C_ID_3d0044924f                             56.0
# C_ID_d639edf6cd                              0.0
# C_ID_186d6a6901                             41.0
# C_ID_cdbd2c0db2                             57.0
#
#                  new_merchant_purchase_date_average  \
# card_id
# C_ID_92a2005557                            2.347826
# C_ID_3d0044924f                            9.333333
# C_ID_d639edf6cd                            0.000000
# C_ID_186d6a6901                            5.857143
# C_ID_cdbd2c0db2                            1.583333
#
#                  new_merchant_purchase_date_uptonow  elapsed_time  \
# card_id
# C_ID_92a2005557                               325.0           657
# C_ID_3d0044924f                               355.0           808
# C_ID_d639edf6cd                               326.0           961
# C_ID_186d6a6901                               336.0           565
# C_ID_cdbd2c0db2                               326.0           504
#
#                  card_id_total  purchase_amount_total
# card_id
# C_ID_92a2005557          283.0            -179.212942
# C_ID_3d0044924f          356.0            -214.362071
# C_ID_d639edf6cd           44.0             -29.867717
# C_ID_186d6a6901           84.0             -54.145736
# C_ID_cdbd2c0db2          169.0             -68.613893
#
# [5 rows x 55 columns]

# %%
df_train.shape
# Out:
# (201917, 55)

# %%
# Affichage entier des colonnes
pd.set_option('display.max_columns', 100)
df_train.head(1)
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  \
# card_id
# C_ID_92a2005557         2017-06-01   0.013145   0.008752   0.011428
#
#                  hist_subsector_id_nunique  hist_purchase_amount_sum  \
# card_id
# C_ID_92a2005557                         21               -165.968739
#
#                  hist_purchase_amount_max  hist_purchase_amount_min  \
# card_id
# C_ID_92a2005557                  2.258395                 -0.739395
#
#                  hist_purchase_amount_mean  hist_purchase_amount_var  \
# card_id
# C_ID_92a2005557                  -0.638341                  0.045003
#
#                  hist_installments_sum  hist_installments_max  \
# card_id
# C_ID_92a2005557                      4                      1
#
#                  hist_installments_min  hist_installments_mean  \
# card_id
# C_ID_92a2005557                      0                0.015385
#
#                  hist_installments_var  hist_month_lag_max  \
# card_id
# C_ID_92a2005557               0.015206                   0
#
#                  hist_month_lag_min  hist_month_lag_mean  hist_month_lag_var  \
# card_id
# C_ID_92a2005557                  -8            -3.911538            5.748901
#
#                  hist_month_diff_mean  hist_category_1_sum  \
# card_id
# C_ID_92a2005557             12.826923                    0
#
#                  hist_category_1_mean  hist_card_id_size  \
# card_id
# C_ID_92a2005557                   0.0                260
#
#                  hist_category_2_mean_mean  hist_category_3_mean_mean  \
# card_id
# C_ID_92a2005557                   0.072502                   0.346719
#
#                  hist_purchase_date_diff  hist_purchase_date_average  \
# card_id
# C_ID_92a2005557                      242                    0.930769
#
#                  hist_purchase_date_uptonow  \
# card_id
# C_ID_92a2005557                         388
#
#                  new_merchant_subsector_id_nunique  \
# card_id
# C_ID_92a2005557                               10.0
#
#                  new_merchant_purchase_amount_sum  \
# card_id
# C_ID_92a2005557                        -13.244202
#
#                  new_merchant_purchase_amount_max  \
# card_id
# C_ID_92a2005557                         -0.296112
#
#                  new_merchant_purchase_amount_min  \
# card_id
# C_ID_92a2005557                         -0.724368
#
#                  new_merchant_purchase_amount_mean  \
# card_id
# C_ID_92a2005557                          -0.575835
#
#                  new_merchant_purchase_amount_var  \
# card_id
# C_ID_92a2005557                          0.018445
#
#                  new_merchant_installments_sum  new_merchant_installments_max  \
# card_id
# C_ID_92a2005557                            0.0                            0.0
#
#                  new_merchant_installments_min  \
# card_id
# C_ID_92a2005557                            0.0
#
#                  new_merchant_installments_mean  \
# card_id
# C_ID_92a2005557                             0.0
#
#                  new_merchant_installments_var  new_merchant_month_lag_max  \
# card_id
# C_ID_92a2005557                            0.0                         2.0
#
#                  new_merchant_month_lag_min  new_merchant_month_lag_mean  \
# card_id
# C_ID_92a2005557                         1.0                     1.478261
#
#                  new_merchant_month_lag_var  new_merchant_month_diff_mean  \
# card_id
# C_ID_92a2005557                     0.26087                     12.695652
#
#                  new_merchant_category_1_sum  new_merchant_category_1_mean  \
# card_id
# C_ID_92a2005557                          0.0                           0.0
#
#                  new_merchant_card_id_size  new_merchant_category_2_mean_mean  \
# card_id
# C_ID_92a2005557                       23.0                           -0.55016
#
#                  new_merchant_category_3_mean_mean  \
# card_id
# C_ID_92a2005557                          -0.592993
#
#                  new_merchant_purchase_date_diff  \
# card_id
# C_ID_92a2005557                             54.0
#
#                  new_merchant_purchase_date_average  \
# card_id
# C_ID_92a2005557                            2.347826
#
#                  new_merchant_purchase_date_uptonow  elapsed_time  \
# card_id
# C_ID_92a2005557                               325.0           657
#
#                  card_id_total  purchase_amount_total
# card_id
# C_ID_92a2005557          283.0            -179.212942

# %%
df_train.columns
# Out:
# Index(['first_active_month', 'feature_1', 'feature_2', 'feature_3',
#        'hist_subsector_id_nunique', 'hist_purchase_amount_sum',
#        'hist_purchase_amount_max', 'hist_purchase_amount_min',
#        'hist_purchase_amount_mean', 'hist_purchase_amount_var',
#        'hist_installments_sum', 'hist_installments_max',
#        'hist_installments_min', 'hist_installments_mean',
#        'hist_installments_var', 'hist_month_lag_max', 'hist_month_lag_min',
#        'hist_month_lag_mean', 'hist_month_lag_var', 'hist_month_diff_mean',
#        'hist_category_1_sum', 'hist_category_1_mean', 'hist_card_id_size',
#        'hist_category_2_mean_mean', 'hist_category_3_mean_mean',
#        'hist_purchase_date_diff', 'hist_purchase_date_average',
#        'hist_purchase_date_uptonow', 'new_merchant_subsector_id_nunique',
#        'new_merchant_purchase_amount_sum', 'new_merchant_purchase_amount_max',
#        'new_merchant_purchase_amount_min', 'new_merchant_purchase_amount_mean',
#        'new_merchant_purchase_amount_var', 'new_merchant_installments_sum',
#        'new_merchant_installments_max', 'new_merchant_installments_min',
#        'new_merchant_installments_mean', 'new_merchant_installments_var',
#        'new_merchant_month_lag_max', 'new_merchant_month_lag_min',
#        'new_merchant_month_lag_mean', 'new_merchant_month_lag_var',
#        'new_merchant_month_diff_mean', 'new_merchant_category_1_sum',
#        'new_merchant_category_1_mean', 'new_merchant_card_id_size',
#        'new_merchant_category_2_mean_mean',
#        'new_merchant_category_3_mean_mean', 'new_merchant_purchase_date_diff',
#        'new_merchant_purchase_date_average',
#        'new_merchant_purchase_date_uptonow', 'elapsed_time', 'card_id_total',
#        'purchase_amount_total'],
#       dtype='object')

# %%
# Retrouver l'index d'une colonne
#df_train.columns.get_loc("new_merchant_purchase_date_max")

# %%
# Retirer les colonnes inutiles du test
listOfOuts = ["new_merchant_purchase_date_max","new_merchant_purchase_date_min",
              "new_merchant_merchant_category_id_nunique",
              "new_merchant_merchant_id_nunique","hist_authorized_flag_mean","hist_authorized_flag_sum",
              "hist_purchase_date_max","hist_purchase_date_min","hist_merchant_id_nunique",
              "hist_merchant_category_id_nunique"]



df_test = df_test.drop(listOfOuts, axis=1)
df_test.head(3)
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  \
# card_id
# C_ID_0ab67a22ab         2017-04-01   0.010479   0.014166   0.011428
# C_ID_130fd0cbdd         2017-01-01   0.010610   0.014166   0.010283
# C_ID_b709037bc5         2017-08-01   0.013145   0.011385   0.011428
#
#                  hist_subsector_id_nunique  hist_purchase_amount_sum  \
# card_id
# C_ID_0ab67a22ab                         12                -40.733733
# C_ID_130fd0cbdd                         12                -49.136513
# C_ID_b709037bc5                          6                  4.528840
#
#                  hist_purchase_amount_max  hist_purchase_amount_min  \
# card_id
# C_ID_0ab67a22ab                  0.235676                 -0.743902
# C_ID_130fd0cbdd                  0.318817                 -0.731881
# C_ID_b709037bc5                  2.525866                 -0.536537
#
#                  hist_purchase_amount_mean  hist_purchase_amount_var  \
# card_id
# C_ID_0ab67a22ab                  -0.599025                  0.036967
# C_ID_130fd0cbdd                  -0.629955                  0.024025
# C_ID_b709037bc5                   0.348372                  0.821827
#
#                  hist_installments_sum  hist_installments_max  \
# card_id
# C_ID_0ab67a22ab                    141                     12
# C_ID_130fd0cbdd                     83                      4
# C_ID_b709037bc5                     44                     10
#
#                  hist_installments_min  hist_installments_mean  \
# card_id
# C_ID_0ab67a22ab                      1                2.073529
# C_ID_130fd0cbdd                      1                1.064103
# C_ID_b709037bc5                     -1                3.384615
#
#                  hist_installments_var  hist_month_lag_max  \
# card_id
# C_ID_0ab67a22ab               4.248244                   0
# C_ID_130fd0cbdd               0.164669                   0
# C_ID_b709037bc5              13.589744                   0
#
#                  hist_month_lag_min  hist_month_lag_mean  hist_month_lag_var  \
# card_id
# C_ID_0ab67a22ab                  -8            -3.632353            6.026997
# C_ID_130fd0cbdd                 -13           -10.410256            4.686647
# C_ID_b709037bc5                  -6            -2.076923            3.076923
#
#                  hist_month_diff_mean  hist_category_1_sum  \
# card_id
# C_ID_0ab67a22ab             14.838235                   23
# C_ID_130fd0cbdd             12.987179                    2
# C_ID_b709037bc5             13.000000                    1
#
#                  hist_category_1_mean  hist_card_id_size  \
# card_id
# C_ID_0ab67a22ab              0.338235                 68
# C_ID_130fd0cbdd              0.025641                 78
# C_ID_b709037bc5              0.076923                 13
#
#                  hist_category_2_mean_mean  hist_category_3_mean_mean  \
# card_id
# C_ID_0ab67a22ab                   0.074568                  -0.239369
# C_ID_130fd0cbdd                  -0.148613                  -0.391464
# C_ID_b709037bc5                  -0.076914                   0.125002
#
#                  hist_purchase_date_diff  hist_purchase_date_average  \
# card_id
# C_ID_0ab67a22ab                      268                    3.941176
# C_ID_130fd0cbdd                      401                    5.141026
# C_ID_b709037bc5                      161                   12.384615
#
#                  hist_purchase_date_uptonow  \
# card_id
# C_ID_0ab67a22ab                         446
# C_ID_130fd0cbdd                         395
# C_ID_b709037bc5                         411
#
#                  new_merchant_subsector_id_nunique  \
# card_id
# C_ID_0ab67a22ab                                3.0
# C_ID_130fd0cbdd                                6.0
# C_ID_b709037bc5                                2.0
#
#                  new_merchant_purchase_amount_sum  \
# card_id
# C_ID_0ab67a22ab                         -1.777156
# C_ID_130fd0cbdd                         -5.944698
# C_ID_b709037bc5                          0.180138
#
#                  new_merchant_purchase_amount_max  \
# card_id
# C_ID_0ab67a22ab                         -0.383266
# C_ID_130fd0cbdd                         -0.506484
# C_ID_b709037bc5                          0.904506
#
#                  new_merchant_purchase_amount_min  \
# card_id
# C_ID_0ab67a22ab                         -0.722114
# C_ID_130fd0cbdd                         -0.740897
# C_ID_b709037bc5                         -0.724368
#
#                  new_merchant_purchase_amount_mean  \
# card_id
# C_ID_0ab67a22ab                          -0.592385
# C_ID_130fd0cbdd                          -0.660522
# C_ID_b709037bc5                           0.090069
#
#                  new_merchant_purchase_amount_var  \
# card_id
# C_ID_0ab67a22ab                          0.033432
# C_ID_130fd0cbdd                          0.005062
# C_ID_b709037bc5                          1.326615
#
#                  new_merchant_installments_sum  new_merchant_installments_max  \
# card_id
# C_ID_0ab67a22ab                            5.0                            3.0
# C_ID_130fd0cbdd                           11.0                            3.0
# C_ID_b709037bc5                           11.0                           10.0
#
#                  new_merchant_installments_min  \
# card_id
# C_ID_0ab67a22ab                            1.0
# C_ID_130fd0cbdd                            1.0
# C_ID_b709037bc5                            1.0
#
#                  new_merchant_installments_mean  \
# card_id
# C_ID_0ab67a22ab                        1.666667
# C_ID_130fd0cbdd                        1.222222
# C_ID_b709037bc5                        5.500000
#
#                  new_merchant_installments_var  new_merchant_month_lag_max  \
# card_id
# C_ID_0ab67a22ab                       1.333333                         2.0
# C_ID_130fd0cbdd                       0.444444                         2.0
# C_ID_b709037bc5                      40.500000                         1.0
#
#                  new_merchant_month_lag_min  new_merchant_month_lag_mean  \
# card_id
# C_ID_0ab67a22ab                         2.0                     2.000000
# C_ID_130fd0cbdd                         1.0                     1.444444
# C_ID_b709037bc5                         1.0                     1.000000
#
#                  new_merchant_month_lag_var  new_merchant_month_diff_mean  \
# card_id
# C_ID_0ab67a22ab                    0.000000                     14.666667
# C_ID_130fd0cbdd                    0.277778                     13.000000
# C_ID_b709037bc5                    0.000000                     13.000000
#
#                  new_merchant_category_1_sum  new_merchant_category_1_mean  \
# card_id
# C_ID_0ab67a22ab                          0.0                      0.000000
# C_ID_130fd0cbdd                          2.0                      0.222222
# C_ID_b709037bc5                          1.0                      0.500000
#
#                  new_merchant_card_id_size  new_merchant_category_2_mean_mean  \
# card_id
# C_ID_0ab67a22ab                        3.0                          -0.550160
# C_ID_130fd0cbdd                        9.0                          -0.555930
# C_ID_b709037bc5                        2.0                          -0.549587
#
#                  new_merchant_category_3_mean_mean  \
# card_id
# C_ID_0ab67a22ab                          -0.391755
# C_ID_130fd0cbdd                          -0.534909
# C_ID_b709037bc5                          -0.284389
#
#                  new_merchant_purchase_date_diff  \
# card_id
# C_ID_0ab67a22ab                             25.0
# C_ID_130fd0cbdd                             48.0
# C_ID_b709037bc5                             11.0
#
#                  new_merchant_purchase_date_average  \
# card_id
# C_ID_0ab67a22ab                            8.333333
# C_ID_130fd0cbdd                            5.333333
# C_ID_b709037bc5                            5.500000
#
#                  new_merchant_purchase_date_uptonow  elapsed_time  \
# card_id
# C_ID_0ab67a22ab                               385.0         718.0
# C_ID_130fd0cbdd                               334.0         808.0
# C_ID_b709037bc5                               372.0         596.0
#
#                  card_id_total  purchase_amount_total
# card_id
# C_ID_0ab67a22ab           71.0             -42.510888
# C_ID_130fd0cbdd           87.0             -55.081212
# C_ID_b709037bc5           15.0               4.708978

# %%
df_test.shape
# Out:
# (123623, 55)

# %%
# Vérification des valeurs manquantes pour le train
df_train.isnull().values.any()
# Out:
# True

# %%
null_columns=df_train.columns[df_train.isnull().any()]
df_train[null_columns].isnull().sum()
# Out:
# new_merchant_subsector_id_nunique     21931
# new_merchant_purchase_amount_sum      21931
# new_merchant_purchase_amount_max      21931
# new_merchant_purchase_amount_min      21931
# new_merchant_purchase_amount_mean     21931
# new_merchant_purchase_amount_var      48718
# new_merchant_installments_sum         21931
# new_merchant_installments_max         21931
# new_merchant_installments_min         21931
# new_merchant_installments_mean        21931
# new_merchant_installments_var         48718
# new_merchant_month_lag_max            21931
# new_merchant_month_lag_min            21931
# new_merchant_month_lag_mean           21931
# new_merchant_month_lag_var            48718
# new_merchant_month_diff_mean          21931
# new_merchant_category_1_sum           21931
# new_merchant_category_1_mean          21931
# new_merchant_card_id_size             21931
# new_merchant_category_2_mean_mean     21931
# new_merchant_category_3_mean_mean     21931
# new_merchant_purchase_date_diff       21931
# new_merchant_purchase_date_average    21931
# new_merchant_purchase_date_uptonow    21931
# card_id_total                         21931
# purchase_amount_total                 21931
# dtype: int64

# %%
# Remplacer les valeur manquantes par 0
df_train = df_train.fillna(0)
df_train.isnull().values.any()
# Out:
# False

# %%
df_train.shape
# Out:
# (201917, 55)

# %%
# Verification des valeurs manquantes pour le test
df_test.isnull().values.any()
# Out:
# True

# %%
null_columns=df_test.columns[df_test.isnull().any()]
df_test[null_columns].isnull().sum()
# Out:
# first_active_month                        1
# new_merchant_subsector_id_nunique     13608
# new_merchant_purchase_amount_sum      13608
# new_merchant_purchase_amount_max      13608
# new_merchant_purchase_amount_min      13608
# new_merchant_purchase_amount_mean     13608
# new_merchant_purchase_amount_var      29831
# new_merchant_installments_sum         13608
# new_merchant_installments_max         13608
# new_merchant_installments_min         13608
# new_merchant_installments_mean        13608
# new_merchant_installments_var         29831
# new_merchant_month_lag_max            13608
# new_merchant_month_lag_min            13608
# new_merchant_month_lag_mean           13608
# new_merchant_month_lag_var            29831
# new_merchant_month_diff_mean          13608
# new_merchant_category_1_sum           13608
# new_merchant_category_1_mean          13608
# new_merchant_card_id_size             13608
# new_merchant_category_2_mean_mean     13608
# new_merchant_category_3_mean_mean     13608
# new_merchant_purchase_date_diff       13608
# new_merchant_purchase_date_average    13608
# new_merchant_purchase_date_uptonow    13608
# elapsed_time                              1
# card_id_total                         13608
# purchase_amount_total                 13608
# dtype: int64

# %%
# Ajouter une date pour pallier le manque
df_test["first_active_month"] = df_test["first_active_month"].fillna("2018-02-01")

# %%
null_columns=df_test.columns[df_test.isnull().any()]
df_test[null_columns].isnull().sum()
# Out:
# new_merchant_subsector_id_nunique     13608
# new_merchant_purchase_amount_sum      13608
# new_merchant_purchase_amount_max      13608
# new_merchant_purchase_amount_min      13608
# new_merchant_purchase_amount_mean     13608
# new_merchant_purchase_amount_var      29831
# new_merchant_installments_sum         13608
# new_merchant_installments_max         13608
# new_merchant_installments_min         13608
# new_merchant_installments_mean        13608
# new_merchant_installments_var         29831
# new_merchant_month_lag_max            13608
# new_merchant_month_lag_min            13608
# new_merchant_month_lag_mean           13608
# new_merchant_month_lag_var            29831
# new_merchant_month_diff_mean          13608
# new_merchant_category_1_sum           13608
# new_merchant_category_1_mean          13608
# new_merchant_card_id_size             13608
# new_merchant_category_2_mean_mean     13608
# new_merchant_category_3_mean_mean     13608
# new_merchant_purchase_date_diff       13608
# new_merchant_purchase_date_average    13608
# new_merchant_purchase_date_uptonow    13608
# elapsed_time                              1
# card_id_total                         13608
# purchase_amount_total                 13608
# dtype: int64

# %%
# Remplacer les valeur manquantes par 0
df_test = df_test.fillna(0)
df_test.isnull().values.any()
# Out:
# False

# %%
df_test.shape
# Out:
# (123623, 55)

# %%
# Transformer le 'first_active_month' en string pour l'utiliser avec notre model
df_train["first_active_month"] = df_train["first_active_month"].astype(str)

# %%
df_train.isnull().values.any()
# Out:
# False

# %%
df_train.dtypes
# Out:
# first_active_month                     object
# feature_1                             float64
# feature_2                             float64
# feature_3                             float64
# hist_subsector_id_nunique               int64
# hist_purchase_amount_sum              float64
# hist_purchase_amount_max              float64
# hist_purchase_amount_min              float64
# hist_purchase_amount_mean             float64
# hist_purchase_amount_var              float64
# hist_installments_sum                   int64
# hist_installments_max                   int64
# hist_installments_min                   int64
# hist_installments_mean                float64
# hist_installments_var                 float64
# hist_month_lag_max                      int64
# hist_month_lag_min                      int64
# hist_month_lag_mean                   float64
# hist_month_lag_var                    float64
# hist_month_diff_mean                  float64
# hist_category_1_sum                     int64
# hist_category_1_mean                  float64
# hist_card_id_size                       int64
# hist_category_2_mean_mean             float64
# hist_category_3_mean_mean             float64
# hist_purchase_date_diff                 int64
# hist_purchase_date_average            float64
# hist_purchase_date_uptonow              int64
# new_merchant_subsector_id_nunique     float64
# new_merchant_purchase_amount_sum      float64
# new_merchant_purchase_amount_max      float64
# new_merchant_purchase_amount_min      float64
# new_merchant_purchase_amount_mean     float64
# new_merchant_purchase_amount_var      float64
# new_merchant_installments_sum         float64
# new_merchant_installments_max         float64
# new_merchant_installments_min         float64
# new_merchant_installments_mean        float64
# new_merchant_installments_var         float64
# new_merchant_month_lag_max            float64
# new_merchant_month_lag_min            float64
# new_merchant_month_lag_mean           float64
# new_merchant_month_lag_var            float64
# new_merchant_month_diff_mean          float64
# new_merchant_category_1_sum           float64
# new_merchant_category_1_mean          float64
# new_merchant_card_id_size             float64
# new_merchant_category_2_mean_mean     float64
# new_merchant_category_3_mean_mean     float64
# new_merchant_purchase_date_diff       float64
# new_merchant_purchase_date_average    float64
# new_merchant_purchase_date_uptonow    float64
# elapsed_time                            int64
# card_id_total                         float64
# purchase_amount_total                 float64
# dtype: object

# %% [markdown]
# # Notre modèle : CatBoostRegressor

# %%
data = df_train
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=789)

# %%
# Initialiser le Pool
train_pool = Pool(X_train, 
                  y_train, 
                  cat_features=[0,4,28])
test_pool = Pool(X_test, 
                 cat_features= [0,4,28])

# %%
# Spécifier les parametres du trainning
model = CatBoostRegressor(iterations=20, 
                          depth=7, 
                          learning_rate=0.3, 
                          loss_function='RMSE')

# %%
model.fit(train_pool)
# Out:
# 0:	learn: 3.8356766	total: 250ms	remaining: 4.76s
# 1:	learn: 3.7894551	total: 355ms	remaining: 3.19s
# 2:	learn: 3.7615212	total: 449ms	remaining: 2.54s
# 3:	learn: 3.7440886	total: 559ms	remaining: 2.23s
# 4:	learn: 3.7319246	total: 664ms	remaining: 1.99s
# 5:	learn: 3.7241104	total: 760ms	remaining: 1.77s
# 6:	learn: 3.7204115	total: 870ms	remaining: 1.62s
# 7:	learn: 3.7144419	total: 971ms	remaining: 1.46s
# 8:	learn: 3.7105946	total: 1.08s	remaining: 1.32s
# 9:	learn: 3.7077311	total: 1.21s	remaining: 1.21s
# 10:	learn: 3.7013104	total: 1.33s	remaining: 1.09s
# 11:	learn: 3.6988460	total: 1.43s	remaining: 953ms
# 12:	learn: 3.6971689	total: 1.55s	remaining: 835ms
# 13:	learn: 3.6950839	total: 1.65s	remaining: 706ms
# 14:	learn: 3.6924113	total: 1.75s	remaining: 585ms
# 15:	learn: 3.6913901	total: 1.88s	remaining: 470ms
# 16:	learn: 3.6852347	total: 1.99s	remaining: 351ms
# 17:	learn: 3.6821008	total: 2.11s	remaining: 234ms
# 18:	learn: 3.6805280	total: 2.23s	remaining: 118ms
# 19:	learn: 3.6758118	total: 2.36s	remaining: 0us

# %%
preds = model.predict(test_pool)
print(preds)
# Out:
# [-0.46460011  0.35042705  0.33927911 ... -0.6433819   0.01117008
#  -0.20801942]

# %%
print("score train :", model.score(X_train, y_train))
print("score test :", model.score(X_test, y_test))
# Out:
# score train : 3.675811855696966
# score test : 3.5588789730252652

# %%
model_pred_train = model.predict(X_train)
model_pred_test = model.predict(X_test)

print("mse train:", mean_squared_error(model_pred_train, y_train))
print("mse test:", mean_squared_error(model_pred_test, y_test))
# Out:
# mse train: 13.511592798482374
# mse test: 12.665619544641368

# %% [markdown]
# # Prédictions pour le  Test

# %%
df_test["first_active_month"] = df_test["first_active_month"].astype(str)

# %%
predictions = model.predict(df_test)

# %%
df_test = df_test.reset_index()

# %%
df_test.head(3)
# Out:
#            card_id   first_active_month  feature_1  feature_2  feature_3  \
# 0  C_ID_0ab67a22ab  2017-04-01 00:00:00   0.010479   0.014166   0.011428
# 1  C_ID_130fd0cbdd  2017-01-01 00:00:00   0.010610   0.014166   0.010283
# 2  C_ID_b709037bc5  2017-08-01 00:00:00   0.013145   0.011385   0.011428
#
#    hist_subsector_id_nunique  hist_purchase_amount_sum  \
# 0                         12                -40.733733
# 1                         12                -49.136513
# 2                          6                  4.528840
#
#    hist_purchase_amount_max  hist_purchase_amount_min  \
# 0                  0.235676                 -0.743902
# 1                  0.318817                 -0.731881
# 2                  2.525866                 -0.536537
#
#    hist_purchase_amount_mean  hist_purchase_amount_var  hist_installments_sum  \
# 0                  -0.599025                  0.036967                    141
# 1                  -0.629955                  0.024025                     83
# 2                   0.348372                  0.821827                     44
#
#    hist_installments_max  hist_installments_min  hist_installments_mean  \
# 0                     12                      1                2.073529
# 1                      4                      1                1.064103
# 2                     10                     -1                3.384615
#
#    hist_installments_var  hist_month_lag_max  hist_month_lag_min  \
# 0               4.248244                   0                  -8
# 1               0.164669                   0                 -13
# 2              13.589744                   0                  -6
#
#    hist_month_lag_mean  hist_month_lag_var  hist_month_diff_mean  \
# 0            -3.632353            6.026997             14.838235
# 1           -10.410256            4.686647             12.987179
# 2            -2.076923            3.076923             13.000000
#
#    hist_category_1_sum  hist_category_1_mean  hist_card_id_size  \
# 0                   23              0.338235                 68
# 1                    2              0.025641                 78
# 2                    1              0.076923                 13
#
#    hist_category_2_mean_mean  hist_category_3_mean_mean  \
# 0                   0.074568                  -0.239369
# 1                  -0.148613                  -0.391464
# 2                  -0.076914                   0.125002
#
#    hist_purchase_date_diff  hist_purchase_date_average  \
# 0                      268                    3.941176
# 1                      401                    5.141026
# 2                      161                   12.384615
#
#    hist_purchase_date_uptonow  new_merchant_subsector_id_nunique  \
# 0                         446                                3.0
# 1                         395                                6.0
# 2                         411                                2.0
#
#    new_merchant_purchase_amount_sum  new_merchant_purchase_amount_max  \
# 0                         -1.777156                         -0.383266
# 1                         -5.944698                         -0.506484
# 2                          0.180138                          0.904506
#
#    new_merchant_purchase_amount_min  new_merchant_purchase_amount_mean  \
# 0                         -0.722114                          -0.592385
# 1                         -0.740897                          -0.660522
# 2                         -0.724368                           0.090069
#
#    new_merchant_purchase_amount_var  new_merchant_installments_sum  \
# 0                          0.033432                            5.0
# 1                          0.005062                           11.0
# 2                          1.326615                           11.0
#
#    new_merchant_installments_max  new_merchant_installments_min  \
# 0                            3.0                            1.0
# 1                            3.0                            1.0
# 2                           10.0                            1.0
#
#    new_merchant_installments_mean  new_merchant_installments_var  \
# 0                        1.666667                       1.333333
# 1                        1.222222                       0.444444
# 2                        5.500000                      40.500000
#
#    new_merchant_month_lag_max  new_merchant_month_lag_min  \
# 0                         2.0                         2.0
# 1                         2.0                         1.0
# 2                         1.0                         1.0
#
#    new_merchant_month_lag_mean  new_merchant_month_lag_var  \
# 0                     2.000000                    0.000000
# 1                     1.444444                    0.277778
# 2                     1.000000                    0.000000
#
#    new_merchant_month_diff_mean  new_merchant_category_1_sum  \
# 0                     14.666667                          0.0
# 1                     13.000000                          2.0
# 2                     13.000000                          1.0
#
#    new_merchant_category_1_mean  new_merchant_card_id_size  \
# 0                      0.000000                        3.0
# 1                      0.222222                        9.0
# 2                      0.500000                        2.0
#
#    new_merchant_category_2_mean_mean  new_merchant_category_3_mean_mean  \
# 0                          -0.550160                          -0.391755
# 1                          -0.555930                          -0.534909
# 2                          -0.549587                          -0.284389
#
#    new_merchant_purchase_date_diff  new_merchant_purchase_date_average  \
# 0                             25.0                            8.333333
# 1                             48.0                            5.333333
# 2                             11.0                            5.500000
#
#    new_merchant_purchase_date_uptonow  elapsed_time  card_id_total  \
# 0                               385.0         718.0           71.0
# 1                               334.0         808.0           87.0
# 2                               372.0         596.0           15.0
#
#    purchase_amount_total
# 0             -42.510888
# 1             -55.081212
# 2               4.708978

# %%
sub_df = pd.DataFrame({"card_id":df_test["card_id"].values})
sub_df["target"] = predictions

sub_df.to_csv("submission_6.csv", index=False)

# %%
sub_df.head(5)
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.125384
# 1  C_ID_130fd0cbdd -0.414614
# 2  C_ID_b709037bc5 -0.526047
# 3  C_ID_d27d835a9f -0.484135
# 4  C_ID_2b5e3df5c2 -1.217794

# %%
# la difference avec la submission 4 (learning_rate=1),est le 5(learning_rate=0.3)
